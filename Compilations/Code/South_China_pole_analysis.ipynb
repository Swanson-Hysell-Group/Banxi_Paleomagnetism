# %%
import pmagpy.ipmag as ipmag
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
((140/19)**2)/10
# Out:
# 5.429362880886426

# %%
#Xiaofeng pole of Li et al. 2004
XF_plon = 91.0
XF_plat = 13.5
XF_kappa = 3
XF_N = 54
XF_age = 821
XF_age_2s = 1

#Yanbian dike pole of Niu et al. 2015
Y_plon = 130.4
Y_plat = 45.1
Y_kappa = ((140/19)**2)/10
Y_N = 10
Y_age = 824
Y_age_2s = 6

#CIT section pole of Evans et al. 2000 
#This study; pole (03.4°N, 163.6°E), Q=7, N=106, k=59, a95=1.8°.
L_plon = 163.6
L_plat = 3.4
L_kappa = 106
L_N = 59
L_age = 778
L_age_2s = 1.5

#Reference location
Yichang_lon = 111.2865
Yichang_lat = 30.6920


ipmag.plate_rate_mc(XF_plon,XF_plat,XF_kappa,XF_N,XF_age,XF_age_2s,
                   Y_plon,Y_plat,Y_kappa,Y_N,Y_age,Y_age_2s,
                    Yichang_lon,Yichang_lat,samplesize=10000)
# Out:
# The paleolatitude for ref_loc resulting from pole 1 is:[64.6157205]
# The paleolatitude for ref_loc resulting from pole 2 is:[69.24201841]
# The rate of paleolatitudinal change implied by the poles pairs in cm/yr is:[17.11730227]
# 2.5th percentile is: -212.09 cm/yr
# 50th percentile is: 2.5 cm/yr
# 97.5th percentile is: 181.9 cm/yr
# (17.11730226948296, -212.09274736767003, 181.90260612259095)

# %%
#Xiaofeng pole of Li et al. 2004
XF_plon = 111.23
XF_plat = 30.96
XF_kappa = 11.2
XF_N = 54
XF_age = 821
XF_age_2s = 1

#CIT section pole of Evans et al. 2000 
#This study; pole (03.4°N, 163.6°E), Q=7, N=106, k=59, a95=1.8°.
L_plon = 163.6
L_plat = 3.4
L_kappa = 106
L_N = 59
L_age = 778
L_age_2s = 1.5

#Reference location
Yichang_lon = 111.2865
Yichang_lat = 30.6920


ipmag.plate_rate_mc(XF_plon,XF_plat,XF_kappa,XF_N,XF_age,XF_age_2s,
                   L_plon,L_plat,L_kappa,L_N,L_age,L_age_2s,
                    Yichang_lon,Yichang_lat,samplesize=10000)
# Out:
# The paleolatitude for ref_loc resulting from pole 1 is:[ 89.72764362]
# The paleolatitude for ref_loc resulting from pole 2 is:[ 33.71430816]
# The rate of paleolatitudinal change implied by the poles pairs in cm/yr is:[ 14.45925636]
# 2.5th percentile is: 12.32 cm/yr
# 50th percentile is: 13.74 cm/yr
# 97.5th percentile is: 15.27 cm/yr
# (14.459256363881774, 12.322809700426005, 15.266306210582973)
