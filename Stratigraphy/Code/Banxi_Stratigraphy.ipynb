# %% [markdown]
# # Banxi_Stratigraphy
#
# This Jupyter notebook plots the lithostratigraphy as well as locations of collected samples.
#
# Python 3 kernel.

# %%
import matplotlib.pyplot as plt

import sys
sys.path.insert(0, '../pyStrat')
from pyStrat import *
# Out:
# /Users/yuempark/anaconda/lib/python3.5/site-packages/statsmodels/compat/pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools

# %% [markdown]
# ## Formatting

# %%
formatting = read_formatting('stratigraphy/master_format.csv')
fig, axs = plot_legend(formatting)
plt.show(fig)

# %% [markdown]
# ## Sections

# %%
def plot_stratigraphy(data, formatting, strat_ratio):
    """
    Plot everything.

    inputs:
    - data = dataframe with stratigraphy data
    - formatting = dataframe with formatting data
    - strat_ratio = the desired scaling ratio for stratigraphic thickness

    outputs:
    - fig = figure handle
    - axs = axis handles
    """
    fig, axs = initiate_figure(data, formatting, strat_ratio, 6, [3,1,1,1], features=False)
    
    add_data_axis(fig, axs, 1, np.zeros(len(data['ASH_HEIGHT'])), data['ASH_HEIGHT'], 'scatter',
                  marker='^',color='firebrick',s=50,edgecolors='k',linewidth=0.5)
    
    add_data_axis(fig, axs, 2, np.zeros(len(data['DZ_HEIGHT'])), data['DZ_HEIGHT'], 'scatter',
                  marker='v',color='crimson',s=50,edgecolors='k',linewidth=0.5)
    
    add_data_axis(fig, axs, 3, np.zeros(len(data['PM_HEIGHT'])), data['PM_HEIGHT'], 'scatter',
                  marker='o',color='dodgerblue',s=10,edgecolors='k',linewidth=0.1)
    
    # prettify
    axs[1].set_title('ashes')
    axs[2].set_title('detritals')
    axs[3].set_title('cores')
    axs[1].set_xticklabels([])
    axs[2].set_xticklabels([])
    axs[3].set_xticklabels([])
    axs[1].set_xticks([])
    axs[2].set_xticks([])
    axs[3].set_xticks([])
    
    # count how many samples/sites there are and print
    n_ash = 0
    for i in range(len(data['ASH_HEIGHT'])):
        if np.isfinite(data['ASH_HEIGHT'][i]):
            n_ash = n_ash + 1
    n_dz = 0
    for i in range(len(data['DZ_HEIGHT'])):
        if np.isfinite(data['DZ_HEIGHT'][i]):
            n_dz = n_dz + 1
    n_pm = 0
    for i in range(len(data['PM_HEIGHT'])):
        if np.isfinite(data['PM_HEIGHT'][i]):
            n_pm = n_pm + 1
    pm_sites = []
    for i in range(len(data['PM_SITE'])):
        if data['PM_SITE'][i] not in pm_sites:
            pm_sites.append(data['PM_SITE'][i])
    print('n ashes     : ' + str(n_ash))
    print('n detritals : ' + str(n_dz))
    print('n cores     : ' + str(n_pm))
    print('-----------')
    print('sites: ' + str(pm_sites))
    
    return fig, axs

# %%
strat_ratio = 0.02
save = False

# %% [markdown]
# ### Hongzixi

# %%
Hongzixi_data = read_data('stratigraphy/Hongzixi_data.csv')
integrity_check(Hongzixi_data, formatting)
# Out:
# Colour and width check passed.

# %%
fig, axs = plot_stratigraphy(Hongzixi_data, formatting, strat_ratio)
if save:
    plt.savefig('stratigraphy/Hongzixi.svg')
plt.show(fig)
# Out:
# n ashes     : 10
# n detritals : 5
# n cores     : 183
# -----------
# sites: ['16TR001', '16TR002', '16TR003', '16TR006', '16TR007', '16TR008', '16TR009', '16TR010', '16TR011', '16TR012', '16TR013', '16TR014', '16TR015']

# %% [markdown]
# ### Mamagou

# %%
Mamagou_data = read_data('stratigraphy/Mamagou_data.csv')
integrity_check(Mamagou_data, formatting)
# Out:
# Colour and width check passed.

# %%
fig, axs = plot_stratigraphy(Mamagou_data, formatting, strat_ratio)
if save:
    plt.savefig('stratigraphy/Mamagou.svg')
plt.show(fig)
# Out:
# n ashes     : 0
# n detritals : 1
# n cores     : 22
# -----------
# sites: ['16TR004']

# %% [markdown]
# ### Mingyaci

# %%
Mingyaci_data = read_data('stratigraphy/Mingyaci_data.csv')
integrity_check(Mingyaci_data, formatting)
# Out:
# Colour and width check passed.

# %%
fig, axs = plot_stratigraphy(Mingyaci_data, formatting, strat_ratio)
if save:
    plt.savefig('stratigraphy/Mingyaci.svg')
plt.show(fig)
# Out:
# n ashes     : 1
# n detritals : 2
# n cores     : 82
# -----------
# sites: ['16TR005', '16TR016', '16TR017', '16TR028', '16TR029']

# %% [markdown]
# ### Quick River

# %%
Quick_River_data = read_data('stratigraphy/Quick_River_data.csv')
integrity_check(Quick_River_data, formatting)
# Out:
# Colour and width check passed.

# %%
fig, axs = plot_stratigraphy(Quick_River_data, formatting, strat_ratio)
if save:
    plt.savefig('stratigraphy/Quick_River.svg')
plt.show(fig)
# Out:
# n ashes     : 1
# n detritals : 1
# n cores     : 108
# -----------
# sites: ['16TR018', '16TR019', '16TR020', '16TR021', '16TR022', '16TR023', '16TR024', '16TR025', '16TR026', '16TR027']

# %% [markdown]
# ### Luoman 1

# %%
Luoman1_data = read_data('stratigraphy/Luoman1_data.csv')
integrity_check(Luoman1_data, formatting)
# Out:
# Colour and width check passed.

# %%
fig, axs = plot_stratigraphy(Luoman1_data, formatting, strat_ratio)
if save:
    plt.savefig('stratigraphy/Luoman_1.svg')
plt.show(fig)
# Out:
# n ashes     : 1
# n detritals : 0
# n cores     : 103
# -----------
# sites: ['16TR030', '16TR031', '16TR032', '16TR033', '16TR034']

# %% [markdown]
# ### Luoman 2

# %%
Luoman2_data = read_data('stratigraphy/Luoman2_data.csv')
integrity_check(Luoman2_data, formatting)
# Out:
# Colour and width check passed.

# %%
fig, axs = plot_stratigraphy(Luoman2_data, formatting, strat_ratio)
if save:
    plt.savefig('stratigraphy/Luoman_2.svg')
plt.show(fig)
# Out:
# n ashes     : 0
# n detritals : 1
# n cores     : 70
# -----------
# sites: ['16TR035', '16TR036', '16TR045']

# %% [markdown]
# ### Luoman 3

# %%
Luoman3_data = read_data('stratigraphy/Luoman3_data.csv')
integrity_check(Luoman3_data, formatting)
# Out:
# Colour and width check passed.

# %%
fig, axs = plot_stratigraphy(Luoman3_data, formatting, strat_ratio)
if save:
    plt.savefig('stratigraphy/Luoman_3.svg')
plt.show(fig)
# Out:
# n ashes     : 1
# n detritals : 0
# n cores     : 89
# -----------
# sites: ['16TR037', '16TR038', '16TR039', '16TR040']

# %% [markdown]
# ### Luoman 4

# %%
Luoman4_data = read_data('stratigraphy/Luoman4_data.csv')
integrity_check(Luoman4_data, formatting)
# Out:
# Colour and width check passed.

# %%
fig, axs = plot_stratigraphy(Luoman4_data, formatting, strat_ratio)
if save:
    plt.savefig('stratigraphy/Luoman_4.svg')
plt.show(fig)
# Out:
# n ashes     : 2
# n detritals : 0
# n cores     : 33
# -----------
# sites: ['16TR041', '16TR042']

# %% [markdown]
# ### Luoman 5

# %%
Luoman5_data = read_data('stratigraphy/Luoman5_data.csv')
integrity_check(Luoman5_data, formatting)
# Out:
# Colour and width check passed.

# %%
fig, axs = plot_stratigraphy(Luoman5_data, formatting, strat_ratio)
if save:
    plt.savefig('stratigraphy/Luoman_5.svg')
plt.show(fig)
# Out:
# n ashes     : 1
# n detritals : 0
# n cores     : 10
# -----------
# sites: ['16TR043']

# %% [markdown]
# ### Luoman 6

# %%
Luoman6_data = read_data('stratigraphy/Luoman6_data.csv')
integrity_check(Luoman6_data, formatting)
# Out:
# Colour and width check passed.

# %%
fig, axs = plot_stratigraphy(Luoman6_data, formatting, strat_ratio)
if save:
    plt.savefig('stratigraphy/Luoman_6.svg')
plt.show(fig)
# Out:
# n ashes     : 1
# n detritals : 0
# n cores     : 15
# -----------
# sites: ['16TR044']

# %% [markdown]
# ### Luoman 7

# %%
Luoman7_data = read_data('stratigraphy/Luoman7_data.csv')
integrity_check(Luoman7_data, formatting)
# Out:
# Colour and width check passed.

# %%
fig, axs = plot_stratigraphy(Luoman7_data, formatting, strat_ratio)
if save:
    plt.savefig('stratigraphy/Luoman_7.svg')
plt.show(fig)
# Out:
# n ashes     : 2
# n detritals : 0
# n cores     : 0
# -----------
# sites: [nan, nan, nan, nan, nan]

# %% [markdown]
# ### Jinzhanpin

# %%
Jinzhanpin_data = read_data('stratigraphy/Jinzhanpin_data.csv')
integrity_check(Jinzhanpin_data, formatting)
# Out:
# Colour and width check passed.

# %%
fig, axs = plot_stratigraphy(Jinzhanpin_data, formatting, strat_ratio)
if save:
    plt.savefig('stratigraphy/Jinzhanpin.svg')
plt.show(fig)
# Out:
# n ashes     : 0
# n detritals : 0
# n cores     : 247
# -----------
# sites: ['16TR047', '16TR048', '16TR049', '16TR050', '16TR051', '16TR052', '16TR053', '16TR054', '16TR055', '16TR056', '16TR057', '16TR058', '16TR059', '16TR060', '16TR061', '16TR062', '16TR063', '16TR064', '16TR065', '16TR066', '16TR067', '16TR068', '16TR069']
